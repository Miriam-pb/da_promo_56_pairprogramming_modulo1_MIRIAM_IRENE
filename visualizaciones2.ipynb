# %%
import pandas as pd

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
pd.set_option('display.max_columns', None)

# %% [markdown]
# ¿Cuál es el continente con la mayor cantidad de países en el conjunto de datos? Proporciona el porcentaje de países en ese continente.
#
# ¿Cuáles son los 10 países con la mayor área forestal?
#
# ¿Cómo se distribuye la densidad de población entre los países?
#
# ¿Existe una relación entre el PIB y la tasa de desempleo de los países?
#
# ¿Cómo se relacionan la tasa de mortalidad infantil y la esperanza de vida?

# %% [markdown]
# quedan las dos ultimas preguntas que son numericas asi que podemos hacer un histograma metiendo un hue o un scatterplot

# %%
df = pd.read_csv('files/world_data_full_apply_nulos.csv.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['country', 'density', 'abbreviation', 'agricultural_land', 'land_area',
#        'armed_forces_size', 'birth_rate', 'calling_code', 'capital/major_city',
#        'co2-emissions', 'cpi', 'cpi_change', 'currency-code', 'fertility_rate',
#        'forested_area', 'gasoline_price', 'gdp',
#        'gross_primary_education_enrollment',
#        'gross_tertiary_education_enrollment', 'infant_mortality',
#        'largest_city', 'life_expectancy', 'maternal_mortality_ratio',
#        'minimum_wage', 'official_language', 'out_of_pocket_health_expenditure',
#        'physicians_per_thousand', 'population',
#        'population_labor_force_participation', 'tax_revenue', 'total_tax_rate',
#        'unemployment_rate', 'urban_population', 'latitude', 'longitude',
#        'continent'],
#       dtype='object')

# %%
df_pais_continente
# Out:
#          continent  country
# 0           Africa       53
# 1             Asia       45
# 2  Central America       20
# 3           Europe       47
# 4    North America        2
# 5          Oceania       14
# 6    South America       13

# %%
df_pais_continente = df.groupby('continent')['country'].count().reset_index()
colores= ['blue','violet','red','brown','pink','orange','turquoise']
plt.pie("country", labels= "continent",
        data = df_pais_continente, 
        autopct=  '%1.1f%%', 
        colors = colores, 
        textprops={'fontsize': 8}, 
        startangle=90);

# %% [markdown]
# conclusion: africa 27.3%

# %%
df['forested_area'].dtype
# Out:
# dtype('float64')

# %%
sns.barplot(x = "forested_area", 
            y = "country", 
            data = df_top10, 
            palette = "magma")
plt.xticks(rotation = 90);
plt.xlabel('area forestal')
plt.ylabel('pais')
plt.title('top 10 paises con mas area forestal')
# Out:
# C:\Users\miria\AppData\Local\Temp\ipykernel_2340\1429750713.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "forested_area",
# Text(0.5, 1.0, 'top 10 paises con mas area forestal')

# %%
df_top10 = df.groupby('forested_area')['country'].max().tail(10).reset_index()

# %%
top10 = df[['country','forested_area']].sort_values(by='forested_area', ascending=False).head(10)

# %%
top10
# Out:
#                             country  forested_area
# 167                        Suriname           98.3
# 111  Federated States of Micronesia           91.9
# 61                            Gabon           90.0
# 154                      Seychelles           88.4
# 132                           Palau           87.6
# 71                           Guyana           83.9
# 92                             Laos           82.1
# 159                 Solomon Islands           77.9
# 135                Papua New Guinea           74.1
# 59                          Finland           73.1

# %%
sns.barplot(x = "density", 
            y = "country", 
            data = df, 
            palette = "magma")
plt.xticks(rotation = 90);
plt.xlabel('')
plt.ylabel('pais')
plt.title('')
# Out:
# C:\Users\miria\AppData\Local\Temp\ipykernel_2340\1846770214.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "density",
# Text(0.5, 1.0, '')

# %%
df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Central America', 'South America',
#        'Oceania', 'North America', nan], dtype=object)

# %%
df_europa = df[df['continent']== 'Europe']
df_asia = df[df['continent'] == 'Asia']
df_africa = df[df['continent'] == 'Africa']
df_south_america = df[df['continent'] == 'South America']
df_central_america = df[df['continent'] == 'Central America']
df_oceania = df[df['continent'] == 'Oceania']
df_north_america = df[df['continent'] == 'North America']

# %%
sns.barplot(x = "density", 
            y = "country", 
            data = df_europa, 
            palette = "magma")
plt.xticks(rotation = 90);
plt.xlabel('')
plt.ylabel('pais')
plt.title('')
plt.tight_layout()
# hacer la densidad por continente y luego enseñar los 10 paises con mas densidad y los 10 con menos en un subplot
# Out:
# C:\Users\miria\AppData\Local\Temp\ipykernel_2340\3426428079.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "density",

# %%
df_europa = df[df['continent'] == 'Europe']

# %%
df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Central America', 'South America',
#        'Oceania', 'North America', nan], dtype=object)

# %%
df_europa
# Out:
#   continent  country
# 0    Europe       47
